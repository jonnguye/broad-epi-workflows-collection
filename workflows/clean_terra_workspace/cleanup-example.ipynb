# %%
import logging
import os
import sys
import json
from datetime import date
from firecloud import api as fapi
from oauth2client.client import GoogleCredentials
sys.path.insert(0, os.path.abspath('../../src/python'))
from terra_workspace_utils import get_workspace_submissions, get_gs_links_for_failed_workflows

#pip install firecloud
logging.basicConfig(filename='workspace-utils-app.log', filemode='w', format='%(name)s - %(levelname)s - %(message)s')

# %%
# Terra workspace in the form of 'namespace/name'
workspace_project = "IGVF_data_analysis"
workspace_namespace = "IGVF-mouse-brain-bridge"

# Get all submissions for a workspace
all_submissions = get_workspace_submissions(workspace_project, workspace_namespace)
print("\n".join(all_submissions[0].keys()))
# Out:
# deleteIntermediateOutputFiles
# methodConfigurationDeleted
# methodConfigurationName
# methodConfigurationNamespace
# status
# submissionDate
# submissionEntity
# submissionId
# submissionRoot
# submitter
# useCallCache
# userComment
# workflowStatuses

# %%
def make_filter_by_date(target_date, newer=True):
    """
    Returns a filter function that filters submissions based on the submission date.

    Parameters:
    - target_date (datetime.date): The target date to filter by.
    - newer (bool, optional): If True, filters submissions with dates greater than the target date.
                              If False, filters submissions with dates less than the target date.
                              Defaults to True.

    Returns:
    - filter_by_date (function): The filter function that can be used to filter submissions.
    """
    def filter_by_date(x):
        if newer:
            return date.fromisoformat(x["submissionDate"].split("T")[0]) > target_date
        else:
            return date.fromisoformat(x["submissionDate"].split("T")[0]) < target_date
    return filter_by_date

def make_filter_by_submitter(email, exclude=False):
    """
    Returns a filter function that filters submissions based on the submitter's email.

    Parameters:
    - email (str): The email of the submitter to filter by.
    - exclude (bool, optional): If True, keep submissions that do not match the email.
                                If False, keep submissions that match the email.
                                Defaults to False.

    Returns:
    - filter_by_submitter (function): The filter function that can be used to filter submissions.
    """
    def filter_by_submitter(x):
        if exclude:
            return x["submitter"] != email
        else:
            return x["submitter"] == email
    return filter_by_submitter

def make_filter_by_workflow_status(status, exclude=False):
    """
    Returns a filter function that filters submissions based on the workflow status.

    Parameters:
    - status (str): The workflow status to filter by.
    - exclude (bool, optional): If True, keep submissions that do not match the status.
                                If False, keep submissions that match the status.
                                Defaults to False.

    Returns:
    - filter_by_workflow_status (function): The filter function that can be used to filter submissions.
    """
    def filter_by_workflow_status(x):
        if exclude:
            return any(x!=status for x in x["workflowStatuses"])
        else:
            return any(x==status for x in x["workflowStatuses"])
    return filter_by_workflow_status

def make_get_links_for_failed_workflows(workspace_project, workspace_namespace):
    """
    Returns a function that gets the Google Storage links for failed workflows in a workspace.

    Parameters:
    - workspace_project (str): The project of the workspace to get the links for.
    - workspace_namespace (str): The namespace of the workspace to get the links for.

    Returns:
    - get_links_for_failed_workflows (function): The function that can be used to get the links for failed workflows.
    """
    def get_links_for_failed_workflows(x):
        return get_gs_links_for_failed_workflows(workspace_project, workspace_namespace, x["submissionId"])
    return get_links_for_failed_workflows

# %%
# Now we can sequentially apply filters to get the submissions we are interested in

# Let's restrict to submissions newer than certain date
target_date = date.fromisoformat("2023-10-01")
submissions_newer_than_target_date = filter(make_filter_by_date(target_date), all_submissions)

# Now let's find which submissions contains Failed or Aborted workflows
failed_submissions = list(filter(make_filter_by_workflow_status("Succeded", exclude=True), submissions_newer_than_target_date))


print(len(failed_submissions))
# Out:
# 131

# %%
folders_to_remove = list(map(make_get_links_for_failed_workflows(workspace_project, workspace_namespace), failed_submissions))
folders_to_remove_cleaned = [x for sublist in folders_to_remove for x in sublist if x]

print(folders_to_remove_cleaned)
with open("folders_to_remove.txt", "w") as f:
    for item in folders_to_remove_cleaned:
        f.write(f"{item}\n")
# Out:
# ['gs://fc-346be0df-e23b-4ecf-95f3-ea8e723369f8/submissions/0109e070-b8bf-48b7-98e8-4bc8a1768f38/combinomics/2166a4b3-f046-462b-ab50-eb5001478063', 'gs://fc-346be0df-e23b-4ecf-95f3-ea8e723369f8/submissions/06808168-377f-443c-8d9e-d3e59e92aa85/combinomics/40b548d3-df48-476e-8fb3-a53c34dd6c8d', 'gs://fc-346be0df-e23b-4ecf-95f3-ea8e723369f8/submissions/06808168-377f-443c-8d9e-d3e59e92aa85/combinomics/84e16d13-ca03-419b-aaf7-a586b3edd252', 'gs://fc-346be0df-e23b-4ecf-95f3-ea8e723369f8/submissions/06808168-377f-443c-8d9e-d3e59e92aa85/combinomics/e6d034d1-2ff5-48e2-afdc-a008ef7a4f4c', 'gs://fc-346be0df-e23b-4ecf-95f3-ea8e723369f8/submissions/06808168-377f-443c-8d9e-d3e59e92aa85/combinomics/99548aff-b4bf-44b2-b965-f5cceecfe6d5', 'gs://fc-346be0df-e23b-4ecf-95f3-ea8e723369f8/submissions/06808168-377f-443c-8d9e-d3e59e92aa85/combinomics/dfcee145-81a8-405f-b65e-36e4f8e5ce84', 'gs://fc-346be0df-e23b-4ecf-95f3-ea8e723369f8/submissions/06808168-377f-443c-8d9e-d3e59e92aa85/combinomics/97e9b500-eeba-444e-9b25-f1f352f2d7b8', 'gs://fc-346be0df-e23b-4ecf-95f3-ea8e723369f8/submissions/06808168-377f-443c-8d9e-d3e59e92aa85/combinomics/a4312475-df8e-498e-b52f-8f3785545c4c', 'gs://fc-346be0df-e23b-4ecf-95f3-ea8e723369f8/submissions/06bd22cb-f90a-4592-9a66-836aa75b63c3/combinomics/fdefb7f1-f965-4453-95cd-8d03b8d99d39', 'gs://fc-346be0df-e23b-4ecf-95f3-ea8e723369f8/submissions/0aa5f528-b0ee-46d4-9ceb-f1d705865b16/wf/2d68ef91-9ff2-4c9f-bf7c-193caf75dc75', 'gs://fc-346be0df-e23b-4ecf-95f3-ea8e723369f8/submissions/0aa5f528-b0ee-46d4-9ceb-f1d705865b16/wf/d02b8d31-975c-4f30-b041-8f8ca4db494a', 'gs://fc-346be0df-e23b-4ecf-95f3-ea8e723369f8/submissions/0aa5f528-b0ee-46d4-9ceb-f1d705865b16/wf/873b0fc6-79c2-46bd-9a37-6569031e78ad', 'gs://fc-346be0df-e23b-4ecf-95f3-ea8e723369f8/submissions/0aa5f528-b0ee-46d4-9ceb-f1d705865b16/wf/21989a1f-7e8b-409d-93bf-fc7b98556f73', 'gs://fc-346be0df-e23b-4ecf-95f3-ea8e723369f8/submissions/0aa5f528-b0ee-46d4-9ceb-f1d705865b16/wf/572593b1-9529-4357-8e89-1e51281f7d4f', 'gs://fc-346be0df-e23b-4ecf-95f3-ea8e723369f8/submissions/0aa5f528-b0ee-46d4-9ceb-f1d705865b16/wf/4aeb413e-8582-4710-88fa-df4cfd0cac42', 'gs://fc-346be0df-e23b-4ecf-95f3-ea8e723369f8/submissions/0aa5f528-b0ee-46d4-9ceb-f1d705865b16/wf/8ecb4c28-2b31-47c2-99e4-823cd0eb9a86', 'gs://fc-346be0df-e23b-4ecf-95f3-ea8e723369f8/submissions/0aa5f528-b0ee-46d4-9ceb-f1d705865b16/wf/b90c3724-d22d-44a9-9e52-dc4c03327631', 'gs://fc-346be0df-e23b-4ecf-95f3-ea8e723369f8/submissions/0aa5f528-b0ee-46d4-9ceb-f1d705865b16/wf/e8198cd1-e633-4064-9288-848038efb9d1', 'gs://fc-346be0df-e23b-4ecf-95f3-ea8e723369f8/submissions/0aa5f528-b0ee-46d4-9ceb-f1d705865b16/wf/0d503dab-452d-4c46-bf24-9abd2847efbd', 'gs://fc-346be0df-e23b-4ecf-95f3-ea8e723369f8/submissions/0aa5f528-b0ee-46d4-9ceb-f1d705865b16/wf/6e05c35a-92d7-4cf1-b463-68b1d50a61f8', 'gs://fc-346be0df-e23b-4ecf-95f3-ea8e723369f8/submissions/0aa5f528-b0ee-46d4-9ceb-f1d705865b16/wf/1d46c1b1-7c8a-480c-a303-e88aa9e55340', 'gs://fc-346be0df-e23b-4ecf-95f3-ea8e723369f8/submissions/0aa5f528-b0ee-46d4-9ceb-f1d705865b16/wf/b444c47f-6f18-4914-983a-ba6f77235393', 'gs://fc-346be0df-e23b-4ecf-95f3-ea8e723369f8/submissions/0aa5f528-b0ee-46d4-9ceb-f1d705865b16/wf/d7882c0c-109f-4971-97ff-57d251f61cf0', 'gs://fc-346be0df-e23b-4ecf-95f3-ea8e723369f8/submissions/0aa5f528-b0ee-46d4-9ceb-f1d705865b16/wf/77e8b4ba-7a3d-4086-9604-5d4ad0dd86b6', 'gs://fc-346be0df-e23b-4ecf-95f3-ea8e723369f8/submissions/0aa5f528-b0ee-46d4-9ceb-f1d705865b16/wf/130df90b-03a2-450e-a134-7aaeb74bca3b', 'gs://fc-346be0df-e23b-4ecf-95f3-ea8e723369f8/submissions/0aa5f528-b0ee-46d4-9ceb-f1d705865b16/wf/c407f56f-b7b7-4731-86ca-ce095630b7c0', 'gs://fc-346be0df-e23b-4ecf-95f3-ea8e723369f8/submissions/0aa5f528-b0ee-46d4-9ceb-f1d705865b16/wf/84824176-6af7-4bdc-90bf-8e55e83cb631', 'gs://fc-346be0df-e23b-4ecf-95f3-ea8e723369f8/submissions/0aa5f528-b0ee-46d4-9ceb-f1d705865b16/wf/faae277b-12cb-4295-8a58-b271225542ed', 'gs://fc-346be0df-e23b-4ecf-95f3-ea8e723369f8/submissions/0aa5f528-b0ee-46d4-9ceb- ...
